# %% [markdown]
# ### Collision detection
#
# If there is one thing NYC is known for, it is road rage. The minute you step in the city it welcomes you with a warm hug of chaotic streets.
# ![image.png](attachment:image.png)
#
# Manoeuvring around the crazies out there while providing our customers with the safe and the best in-car experience hasn't been easy.
#
# So we are stepping up and calling the Superman to the rescue!
# Well, not exactly. But we are building an in-house collision detection system that alerts our drivers of speeding cars, especially the ones that come out of nowhere.

# %% [markdown]
# ##### Level 1
#
# Write-up a simple algorthm in the space provided below to detect whether two vehicle objects would colide. Note that here we are treating objects as a mere point objects.
# In all your calculation round up velocity values up to the 2nd decimal point.
#
# Here's a visualization of the positions of the vehicles around you:
#
# ![vehicles-pos.png](attachment:vehicles-pos.png)

# %%
import numpy as np
        
class Vehicle:
    def __init__(self, x, y, v, theta, radius=None):
        self.pos = (x, y)
        self.velocity = v
        self.theta = theta
        self.radius = radius

you = Vehicle(0, 0, 30, np.pi/2)
v1 = Vehicle(-1, 0, 20 * pow(2, 0.5), np.pi/4)
v2 = Vehicle(0, 1, 30, np.pi/3)
v3 = Vehicle(1, 1, 15 * pow(2, 0.5), 3*np.pi/4)

# %%
def collision_detection(vehicle1, vehicle2):
    #Write code here vehicle1, vehicle2 --> bool (True if collides, False otherwise)
    return NotImplemented

# %%
import module
module.check_p4q1(you, v1, v2, v3, collision_detection)
# Out:
# 'Incorrect. Try Again!'

# %% [markdown]
# ##### Level 2

# %% [markdown]
# Now, let's step up! In reality, collision detection systems can't ignore the dimensions of vehicles on the road. Incorporating the actual dimensions of vehicles in the system is a rather difficult task, but the first step towards this is to treat them as spheres of different radii, that enclose the actual vehicle.
#
# How do you think this would change your collision detection algorithm? Write up an algorithm to incorporate the vehicle radius below.
#
# Note round up all the velocities in your calculations to 2 decimal points.

# %%
def collision_detection_1(vehicle1, vehicle2):
    #Write code here vehicle1, vehicle2 --> bool (True if collides, False otherwise)
    return NotImplemented

def quadratic_equation_solver(a, b, c):
    x = pow(b, 2) - 4*a*c
    if x < 0:
        return None
    elif x == 0:
        return -b/(2*a)
    else:
        return ((-b + pow(x, 0.5))/(2*a), (-b - pow(x, 0.5))/(2*a))

you = Vehicle(0, 0, 30, np.pi/2, 0.05)
v1 = Vehicle(-1, 0, 20 * pow(2, 0.5), np.pi/4, 0.4)
v2 = Vehicle(0, 1, 30, np.pi/3, 0.05)
v3 = Vehicle(1, 1, 15 * pow(2, 0.5), 3*np.pi/4, 0.1)

# %%
import module
module.check_p4q2(you, v1, v2, v3, collision_detection_1)
# Out:
# 'Incorrect. Try Again!'
